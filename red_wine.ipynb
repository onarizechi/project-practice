# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# we can see there are no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %%
#checking number of unique values in each column
df.nunique().to_frame("No. of unique values")
# Out:
#                       No. of unique values
# fixed acidity                           96
# volatile acidity                       143
# citric acid                             80
# residual sugar                          91
# chlorides                              153
# free sulfur dioxide                     60
# total sulfur dioxide                   144
# density                                436
# pH                                      89
# sulphates                               96
# alcohol                                 65
# quality                                  6

# %% [markdown]
# These are the unique values present in the dataset. Here Density can be dropped since the it has the highest count of unique values

# %%
#Dropping Density Column
df.drop("density",axis = 1, inplace = True)

# %%
#To check if density column has been dropped
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                 11.0                  34.0  3.51       0.56      9.4
# 1                 25.0                  67.0  3.20       0.68      9.8
# 2                 15.0                  54.0  3.26       0.65      9.8
# 3                 17.0                  60.0  3.16       0.58      9.8
# 4                 11.0                  34.0  3.51       0.56      9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
print ("Total Duplicate rows are: ",df.duplicated().sum())
# Out:
# Total Duplicate rows are:  240

# %%
# Drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1359, 11)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide           pH  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     3.309787
# std       0.049377            10.447270             33.408946     0.155036
# ...

# %% [markdown]
# From the statistical summary, We can observe the following
#
# 1)The counts of all columns are the same, there is no missing values in the dataset
# 2)The mean value is greater than the median(50%)in most columns, this means that the data is skewed to the right but skewed to the left in PH and quantity columns
# 3)There is a huge diference between 75% and max meaning there are outliers present in the dataset
# 4)We can also notice the standard deviation,min and 25% percentile values

# %%
#to show the descriptive dataset using heatmap
plt.figure(figsize = (22,10))
sns.heatmap(df.describe(), annot= True, fmt = '0.2f', linewidth = 0.2,linecolor = 'black',cmap = 'Spectral')
plt.xlabel('Figure', fontsize = 14)
plt.ylabel('Features_Name', fontsize = 14)
plt.title('Descriptive Graph', fontsize = 20)
plt.show()

# %% [markdown]
# Univariate Analysis

# %%
# Visualise the count of fixed acidity
ax = sns.countplot(x="fixed acidity",data = df)
print(df['fixed acidity'].value_counts())
# Out:
# 7.2     49
# 7.8     48
# 7.1     46
# 7.0     44
# 7.5     42
#         ..
# 13.8     1
# 13.4     1
# 4.7      1
# 15.0     1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64

# %%
# Visualise the count of volatile acidity
ax = sns.countplot(x="volatile acidity",data = df)
print(df['volatile acidity'].value_counts())
# Out:
# 0.500    37
# 0.580    36
# 0.400    35
# 0.600    34
# 0.430    33
#          ..
# 1.185     1
# 1.240     1
# 0.845     1
# 0.365     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64

# %%
# Visualise the count of citric acid
ax = sns.countplot(x="citric acid",data = df)
print(df['citric acid'].value_counts())
# Out:
# 0.00    118
# 0.49     59
# 0.24     41
# 0.02     38
# 0.08     32
#        ...
# 0.72      1
# 0.62      1
# 0.71      1
# 0.79      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64

# %%
sns.lmplot(x = 'fixed acidity',y = 'volatile acidity',data = df, palette = 'colorblind')

# %% [markdown]
# it can be seen that volatile acidity has a negative correlation with fixed acidity

# %%
sns.lmplot(x = 'fixed acidity',y = 'citric acid',data = df, palette = 'colorblind')

# %% [markdown]
# Citric acid has a positive correlation with fixed acidity

# %%
plt.figure(figsize=(20, 25))
p = 1

# Loop through each column in the DataFrame
for i in df.columns:
    if p <= 11 and i != 'fixed acidity':  # Skip 'fixed acidity' itself
        plt.subplot(5, 4, p)
        sns.regplot(x='fixed acidity', y=i, data=df, color='r')
        plt.xlabel("fixed acidity")
        plt.ylabel(i)
        p += 1  # Increment p only if a subplot is created

plt.tight_layout()  # Adjust subplot layout
plt.show()

# %%
sns.pairplot(data = df,palette = "Dark2")
plt.show()

# %%
# checking for outliers by plotting boxplot
plt.figure(figsize = (20,25),facecolor ='white')
plotnumber = 1
for i in df:
    if plotnumber<=11:
        plt.subplot(5,4,plotnumber)
        sns.boxplot(df[i],palette = "Set2_r")
        plt.xlabel(i)
        
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# We have found outliers in all the columns and will be removing using them using zscore and IQR techniques

# %%
from scipy.stats import zscore
out_features = df [['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 
       'pH', 'sulphates', 'alcohol', 'quality']]
z = np.abs(zscore(out_features))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.524431          0.932000     1.393258        0.461157   0.245623
# 1          0.294063          1.915800     1.393258        0.056665   0.200094
# 2          0.294063          1.259934     1.188617        0.165259   0.078535
# 3          1.664067          1.363534     1.471711        0.461157   0.265883
# 5          0.524431          0.713378     1.393258        0.535132   0.265883
# ...             ...               ...          ...             ...        ...
# 1593       0.869983          0.494756     0.983977        0.461157   0.407702
# 1594       1.215536          0.385444     0.983977        0.387183   0.038015
# 1595       1.388312          0.112167     0.881656        0.239233   0.529261
# 1597       1.388312          0.631395     0.779336        0.387183   0.265883
# 1598       1.330720          1.199567     1.011270        0.796410   0.427962
#
# ...

# %%
df1 = df[(z<3).all(axis = 1)]
df1.shape
# Out:
# (1236, 11)

# %%
#lets visualize how the data has been distributed in children column after removing skewness
plt.figure(figsize = (20,25),facecolor ='green')
plotnumber = 1
for i in df:
    if plotnumber<=11:
        plt.subplot(5,4,plotnumber)
        sns.distplot(df[i],color = "b")
        plt.xlabel(i, fontsize = 20)
        
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
df.skew()
# Out:
# fixed acidity           0.941041
# volatile acidity        0.729279
# citric acid             0.312726
# residual sugar          4.548153
# chlorides               5.502487
# free sulfur dioxide     1.226579
# total sulfur dioxide    1.540368
# pH                      0.232032
# sulphates               2.406505
# alcohol                 0.859841
# quality                 0.192407
# dtype: float64

# %%
#removing skewness using cuberoot method
df['residual sugar'] = np.cbrt(df['residual sugar'])
df['chlorides'] = np.cbrt(df['chlorides'])
df['free sulfur dioxide'] = np.cbrt(df['free sulfur dioxide'])
df['total sulfur dioxide'] = np.cbrt(df['total sulfur dioxide'])
df['sulphates'] = np.cbrt(df['sulphates'])

# %%
df.skew()
# Out:
# fixed acidity           0.941041
# volatile acidity        0.729279
# citric acid             0.312726
# residual sugar          1.990909
# chlorides               2.281336
# free sulfur dioxide    -0.060978
# total sulfur dioxide    0.076694
# pH                      0.232032
# sulphates               1.083697
# alcohol                 0.859841
# quality                 0.192407
# dtype: float64

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.169539          0.017979     0.169410
# chlorides                  0.157901          0.102528     0.189379
# free sulfur dioxide       -0.161254         -0.001084    -0.068502
# total sulfur dioxide      -0.109862          0.068311     0.015436
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.210146         -0.294698     0.342814
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.169539   0.157901            -0.161254
# ...
